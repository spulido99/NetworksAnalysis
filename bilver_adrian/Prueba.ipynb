# %%
from scipy.stats import beta
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
a =  2
b = 2
x = np.linspace(0, 1.0, 100)
y1 = beta.pdf(x, 2.75, 2.75)
y2 = beta.pdf(x, 3.25, 3.25)
y3 = beta.pdf(x, 3, 3)
# Out:
# [<matplotlib.lines.Line2D at 0x1476381f160>,
#  <matplotlib.lines.Line2D at 0x1476381f358>,
#  <matplotlib.lines.Line2D at 0x1476381fcf8>]

# %%
plt.plot(x, y1, "-", x, y2, "r--", x, y3, "g--")
# Out:
# [<matplotlib.lines.Line2D at 0x147638d4390>,
#  <matplotlib.lines.Line2D at 0x147638d4588>,
#  <matplotlib.lines.Line2D at 0x147638d4f28>]
